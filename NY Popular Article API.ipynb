# %%
import json
import requests
import pandas as dataframe
import pandas as pd

# %%
url = 'http://api.nytimes.com/svc/mostpopular/v2/mostviewed/business/7.json?api-key=d50955abe9630b297dd92ebab442b122%3A8%3A73272974'

# %%
r = requests.get(url)

# %%
print (r.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2015 The New York Times Company.  All Rights Reserved.","num_results":63,"results":[{"url":"http:\/\/www.nytimes.com\/2015\/10\/21\/business\/the-myth-of-welfares-corrupting-influence-on-the-poor.html","adx_keywords":"Welfare (US);Poverty;United States Politics and Government;Ryan, Paul D Jr;Massachusetts Institute of Technology;World Bank;University of California, Berkeley;University of Kentucky;Clinton, Bill;Reagan, Ronald Wilson;Roosevelt, Franklin Delano;Murray, Charles Alan (1943- )","column":"Economic Scene","section":"Business Day","byline":"By EDUARDO PORTER","type":"Article","title":"The Myth of Welfare\u2019s Corrupting Influence on the Poor","abstract":"Studies rebut a long-cherished belief in America, on the right and left, that welfare encourages bad behavior by the poor.","published_date":"2015-10-21","source":"The New York Times","id":100000003985481,"asset_id":100000003985481,"views":1,"des_facet":["WELFARE (US)","UNITED STATES POLITICS AND GOVERNMENT"],"org_facet":["MASSACHUSETTS INSTITUTE OF TECHNOLOGY","WORLD BANK","UNIVERSITY OF CALIFORNIA, BERKELEY","UNIVERSITY OF KENTUCKY"],"per_facet":["RYAN, PAUL D JR","CLINTON, BILL","REAGAN, RONALD WILSON","ROOSEVELT, FRANKLIN DELANO","MURRAY, CHARLES ALAN (1943- )"],"geo_facet":"","media":[{"type":"image","subtype":"photo","caption":"Deven Thompson, 14, outside his home in Richardson, Ky., in June 2014. Deven and his mother, Roxann Thompson, depended on government assistance to get by.","copyright":"Luke Sharrett for The New York Times","media-metadata":[{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/21porter-web\/21porter-web-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75},{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/21porter-web\/21porter-web-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210},{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/21porter-web\/21porter-web-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440}]}]},{"url":"http:\/\/www.nytimes.com\/2015\/10\/20\/business\/many-low-income-workers-say-no-to-health-insurance.html","adx_keywords":"Health Insurance and Managed Care;Patient Protection and Affordable Care Act (2010);Small Business;Wages and Salaries;Labor and Jobs;Golden Corral Corp","column":"","section":"Business Day","byline":"By STACY COWLEY","type":"Article","title":"Many Low-Income Workers Say \u2018No\u2019 to Health Insurance","abstract":"The Affordable Care Act requires employers with more than 50 full-time workers to offer insurance, but many find few low-income employees will buy it.","published_date":"2015-10-20","source":"The New York Times","id":100000003895402,"asset_id":100000003895402,"views":2,"des_facet":["HEALTH INSURANCE AND MANAGED CARE","SMALL BUSINESS","WAGES AND SALARIES","LABOR AND JOBS"],"org_facet":["GOLDEN CORRAL CORP"],"per_facet":"","geo_facet":"","media":[{"type":"image","subtype":"photo","caption":"An employee at Golden Corral taking clean cups from the kitchen. Some Golden Corral restaurants began offering health insurance to employees, but few have opted in.","copyright":"Logan R. Cyrus for The New York Times","media-metadata":[{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/20BIZMANDATE-web1\/20BIZMANDATE-web1-thumbStandard.jpg","format":"Standard Thumbnail","height":75,"width":75},{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/20BIZMANDATE-web1\/20BIZMANDATE-web1-mediumThreeByTwo210.jpg","format":"mediumThreeByTwo210","height":140,"width":210},{"url":"http:\/\/static01.nyt.com\/images\/2015\/10\/20\/business\/20BIZMANDATE-web1\/20BIZMANDATE-web1-mediumThreeByTwo440.jpg","format":"mediumThreeByTwo440","height":293,"width":440}]}]},{"url":"http:\/\/www.nytimes.com\/2015\/10\/21\/business\/consumer-reports-stops-recommending-the-tesla.html","adx_keywords":"Tesla Motors Inc;Consumer Reports;Te ...

# %%
nyarticles = json.loads(r.text)

# %%
print (nyarticles["results"])
# Out:
# [{'source': 'The New York Times', 'asset_id': 100000003985481, 'per_facet': ['RYAN, PAUL D JR', 'CLINTON, BILL', 'REAGAN, RONALD WILSON', 'ROOSEVELT, FRANKLIN DELANO', 'MURRAY, CHARLES ALAN (1943- )'], 'views': 1, 'des_facet': ['WELFARE (US)', 'UNITED STATES POLITICS AND GOVERNMENT'], 'id': 100000003985481, 'org_facet': ['MASSACHUSETTS INSTITUTE OF TECHNOLOGY', 'WORLD BANK', 'UNIVERSITY OF CALIFORNIA, BERKELEY', 'UNIVERSITY OF KENTUCKY'], 'byline': 'By EDUARDO PORTER', 'geo_facet': '', 'column': 'Economic Scene', 'media': [{'caption': 'Deven Thompson, 14, outside his home in Richardson, Ky., in June 2014. Deven and his mother, Roxann Thompson, depended on government assistance to get by.', 'copyright': 'Luke Sharrett for The New York Times', 'subtype': 'photo', 'media-metadata': [{'url': 'http://static01.nyt.com/images/2015/10/20/business/21porter-web/21porter-web-thumbStandard.jpg', 'height': 75, 'format': 'Standard Thumbnail', 'width': 75}, {'url': 'http://static01.nyt.com/images/2015/10/20/business/21porter-web/21porter-web-mediumThreeByTwo210.jpg', 'height': 140, 'format': 'mediumThreeByTwo210', 'width': 210}, {'url': 'http://static01.nyt.com/images/2015/10/20/business/21porter-web/21porter-web-mediumThreeByTwo440.jpg', 'height': 293, 'format': 'mediumThreeByTwo440', 'width': 440}], 'type': 'image'}], 'adx_keywords': 'Welfare (US);Poverty;United States Politics and Government;Ryan, Paul D Jr;Massachusetts Institute of Technology;World Bank;University of California, Berkeley;University of Kentucky;Clinton, Bill;Reagan, Ronald Wilson;Roosevelt, Franklin Delano;Murray, Charles Alan (1943- )', 'published_date': '2015-10-21', 'url': 'http://www.nytimes.com/2015/10/21/business/the-myth-of-welfares-corrupting-influence-on-the-poor.html', 'type': 'Article', 'section': 'Business Day', 'abstract': 'Studies rebut a long-cherished belief in America, on the right and left, that welfare encourages bad behavior by the poor.', 'title': 'The Myth of Welfare’s Corrupting Influence on the Poor'}, {'source': 'The New York Times', 'asset_id': 100000003895402, 'per_facet': '', 'views': 2, 'des_facet': ['HEALTH INSURANCE AND MANAGED CARE', 'SMALL BUSINESS', 'WAGES AND SALARIES', 'LABOR AND JOBS'], 'id': 100000003895402, 'org_facet': ['GOLDEN CORRAL CORP'], 'byline': 'By STACY COWLEY', 'geo_facet': '', 'column': '', 'media': [{'caption': 'An employee at Golden Corral taking clean cups from the kitchen. Some Golden Corral restaurants began offering health insurance to employees, but few have opted in.', 'copyright': 'Logan R. Cyrus for The New York Times', 'subtype': 'photo', 'media-metadata': [{'url': 'http://static01.nyt.com/images/2015/10/20/business/20BIZMANDATE-web1/20BIZMANDATE-web1-thumbStandard.jpg', 'height': 75, 'format': 'Standard Thumbnail', 'width': 75}, {'url': 'http://static01.nyt.com/images/2015/10/20/business/20BIZMANDATE-web1/20BIZMANDATE-web1-mediumThreeByTwo210.jpg', 'height': 140, 'format': 'mediumThreeByTwo210', 'width': 210}, {'url': 'http://static01.nyt.com/images/2015/10/20/business/20BIZMANDATE-web1/20BIZMANDATE-web1-mediumThreeByTwo440.jpg', 'height': 293, 'format': 'mediumThreeByTwo440', 'width': 440}], 'type': 'image'}], 'adx_keywords': 'Health Insurance and Managed Care;Patient Protection and Affordable Care Act (2010);Small Business;Wages and Salaries;Labor and Jobs;Golden Corral Corp', 'published_date': '2015-10-20', 'url': 'http://www.nytimes.com/2015/10/20/business/many-low-income-workers-say-no-to-health-insurance.html', 'type': 'Article', 'section': 'Business Day', 'abstract': 'The Affordable Care Act requires employers with more than 50 full-time workers to offer insurance, but many find few low-income employees will buy it.', 'title': 'Many Low-Income Workers Say ‘No’ to Health Insurance'}, {'source': 'The New York Times', 'asset_id': 100000003988672, 'per_facet': '', 'views': 3, 'des_facet': ['AUTOMOBILE SAFETY FEATURES AND DEFECTS'], 'id': 100000003988672, 'org_facet': ['TESLA MOTORS INC', 'CONSUMER REPORTS' ...

# %%
urls=[]
columns=[]
bylines=[]
titles=[]
abstracts=[]

for item in nyarticles['results']:
    print (item["url"])
    urls.append("url")
    print (item["column"])
    columns.append("column")
    print (item["byline"])
    bylines.append("byline")
    print (item["title"])
    titles.append("title")
    print (item["abstract"])
    abstracts.append("abstract")
# Out:
# http://www.nytimes.com/2015/10/21/business/the-myth-of-welfares-corrupting-influence-on-the-poor.html
# Economic Scene
# By EDUARDO PORTER
# The Myth of Welfare’s Corrupting Influence on the Poor
# Studies rebut a long-cherished belief in America, on the right and left, that welfare encourages bad behavior by the poor.
# http://www.nytimes.com/2015/10/20/business/many-low-income-workers-say-no-to-health-insurance.html
#
# By STACY COWLEY
# Many Low-Income Workers Say ‘No’ to Health Insurance
# The Affordable Care Act requires employers with more than 50 full-time workers to offer insurance, but many find few low-income employees will buy it.
# http://www.nytimes.com/2015/10/21/business/consumer-reports-stops-recommending-the-tesla.html
#
# By JAD MOUAWAD
# Consumer Reports Stops Recommending the Tesla
# Consumer Reports dropped its endorsement of the Tesla Model S after owners complained about squeaks, failing door handles and motors in need of replacement.
# http://www.nytimes.com/2015/10/18/business/a-small-indiana-town-scarred-by-a-trusted-doctor.html
#
# By JULIE CRESWELL
# A Small Indiana Town Scarred by a Trusted Doctor
# Nearly 300 patients have filed lawsuits against a local cardiologist and his two partners, claiming that they performed needless operations.
# http://www.nytimes.com/2015/10/20/business/dealbook/mistrial-is-declared-indewey-leboeuf-case.html
#
# By MATTHEW GOLDSTEIN
# Mistrial Is Declared in Dewey &amp; LeBoeuf Case
# The jurors had already acquitted three former leaders of the law firm on dozens of charges and said they were “hopelessly deadlocked” on the rest.
# http://www.nytimes.com/2015/10/20/business/amazon-spars-with-the-times-over-investigative-article.html
#
# By NICK WINGFIELD and RAVI SOMAIYA
# Amazon Spars With The Times Over Investigative Article
# An article published in The New York Times two months ago, detailing Amazon&#8217;s work culture, drew a lengthy response on Monday from the company&#8217;s senior vice president for global corporate affairs.
# http://www.nytimes.com/2015/10/25/business/energy-environment/americas-heartland-feels-a-chill-from-collapsing-commodity-prices.html
#
# By NELSON D. SCHWARTZ and JULIE CRESWELL
# A Global Chill in Commodity Demand Hits America’s Heartland
# In China and other emerging markets, growth is waning and demand for the raw materials that drive the global economy has dried up.
# http://www.nytimes.com/2015/10/23/business/international/volkswagen-diesel-investigation.html
#
# By JACK EWING
# Volkswagen Investigating if Diesel Emissions Deception Was More Extensive
# The automaker said it was looking into whether a second motor type, in a limited number of cars, violated European emissions rules.
# http://www.nytimes.com/2015/10/19/business/the-owner-has-a-crucial-part-in-volkswagen-diesel-repair.html
#
# By CHRISTOPHER JENSEN
# Essential Part of the Volkswagen Diesel Repair Is the Owner
# For the most part, owners are not required to have repairs made to Volkswagen cars whose emissions systems were modified to cheat federal tests.
# http://www.nytimes.com/2015/10/26/business/ex-im-bank-dispute-threatens-ge-factory-that-obama-praised.html
#
# By STEVE LOHR
# Ex-Im Bank Dispute Threatens G.E. Factory That Obama Praised
# G.E. plans to close an engine factory in Waukesha, Wis., that President Obama visited in 2014 and move hundreds of jobs to Canada because of the bank’s closure.
# http://www.nytimes.com/2015/10/21/business/dealbook/after-technical-snag-fury-and-no-cash.html
#
# By LIZ MOYER and JESSICA SILVER-GREENBERG
# RushCard Breakdown Affects Thousands of Prepaid Debit Card Users
# The troubles, lasting much of the past week, illustrate the potential perils for those without access to the banking system.
# http://www.nytimes.com/2015/10/17/business/putting-numbers-to-a-tax-increase-for-the-rich.html
#
# By PATRICIA COHEN
# What Could Raising Taxes on the 1% Do? Surprising Amounts
# A tax-the-rich plan could raise enough to, for example, eliminate all public undergraduate tuition while still allowing wealthy individuals to take home a majority of their income, economists argue.
# http://www.nytimes.com/2015/10/20/business/international/discordant-financial-messages-from-china-spur-global-unease.html
# News Analysis
# By NEIL GOUGH
# Discordant Financial Messages From China Spur Global Unease
# Conflicting signals about the direction of the country’s economy are creating volatility in world markets and causing consternation among policy makers.
# http://www.nytimes.com/2015/10/25/business/media/charlie-hebdos-recovery-from-attacks-opens-new-wounds-for-staff.html
#
# By NICOLA CLARK
# Charlie Hebdo’s Recovery From Attacks Opens New Wounds for Staff
# In the nine months since gunmen killed 12 people at the satirical paper’s headquarters in Paris, a surge in readers and revenue has divided employees.
# http://www.nytimes.com/2015/10/21/business/23andme-will-resume-giving-users-health-data.html
#
# By ANDREW POLLACK
# 23andMe Will Resume Giving Users Health Data
# The genetic-testing company stopped providing health information in 2013 after the F.D.A. ordered it to prove the accuracy of results.
# http://www.nytimes.com/2015/10/20/business/drug-makers-sidestep-barriers-on-pricing.html
#
# By ANDREW POLLACK
# Drug Makers Sidestep Barriers on Pricing
# Use of mail-order specialty pharmacies seems to be a new way for drug makers to try to keep the health system paying for high-priced drugs.
# http://www.nytimes.com/2015/08/16/technology/inside-amazon-wrestling-big-ideas-in-a-bruising-workplace.html
#
# By JODI KANTOR and DAVID STREITFELD
# Inside Amazon: Wrestling Big Ideas in a Bruising Workplace
# The company is conducting an experiment in how far it can push white-collar workers to get them to achieve its ever-expanding ambitions.
# http://www.nytimes.com/2015/10/23/business/media/airbnb-ads-flop-in-san-francisco.html
#
# By SYDNEY EMBER and MIKE ISAAC
# Airbnb Ads Flop in San Francisco
# The company is apologizing for a series of ads highlighting how much its guests and hosts contribute in taxes, saying they struck “the wrong tone.”
# http://www.nytimes.com/2015/10/19/business/walmart-chief-defends-investments-in-labor-stores-and-the-web.html
#
# By JULIE CRESWELL and HIROKO TABUCHI
# Walmart Chief Defends Investments in Labor, Stores and the Web
# The retail giant forecast lackluster sales growth for this year and a steep profit dip for next, in part because costs are climbing sharply as sales are flat.
# http://www.nytimes.com/2015/10/20/business/dealbook/a-bloomberg-run-drums-are-beating.html
# DealBook Column
# By ANDREW ROSS SORKIN
# Michael Bloomberg for President? Wall Street’s Drums Are Beating
# The business community&#8217;s interest in a presidential run by the media and data magnate and former mayor of New York has been getting stronger.

# %%
columns = {'URL': urls, 'Column': columns, 'By': bylines, 'Title': titles, "Abstract": abstracts}
df = pd.DataFrame(columns)
df
# Out:
#     Abstract      By  Column  Title  URL
# 0   abstract  byline  column  title  url
# 1   abstract  byline  column  title  url
# 2   abstract  byline  column  title  url
# 3   abstract  byline  column  title  url
# 4   abstract  byline  column  title  url
# 5   abstract  byline  column  title  url
# 6   abstract  byline  column  title  url
# 7   abstract  byline  column  title  url
# 8   abstract  byline  column  title  url
# 9   abstract  byline  column  title  url
# 10  abstract  byline  column  title  url
# 11  abstract  byline  column  title  url
# 12  abstract  byline  column  title  url
# 13  abstract  byline  column  title  url
# 14  abstract  byline  column  title  url
# 15  abstract  byline  column  title  url
# 16  abstract  byline  column  title  url
# 17  abstract  byline  column  title  url
# 18  abstract  byline  column  title  url
# 19  abstract  byline  column  title  url
